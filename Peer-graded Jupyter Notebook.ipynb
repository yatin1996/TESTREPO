# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Yatin Gupta**

# %% [markdown]
# Support Team Data Analyst

# %% [markdown]
# *Data science is one of the broadest fields available for individuals with a mathematical or statistical background. There are plenty of open positions that require data science skills.*

# %% [markdown]
# ### The following code sets a numeric variable to 0, then adds 1 to the variable. The value is printed in a sentence.

# %%
a= 0
a= a + 1
print("The value of a is", a)
# Out:
# The value of a is 1

# %% [markdown]
# #### Here's my company logo (hover over to see title text):
# ![alt text](https://i.ibb.co/BzV8Cxd/RRD-official-logo.png "R. R. Donnelley")
#
#
# Some of my duties include
# =====================
# 1. Customer and vendor inbound data through FTP automated process and email.
# 1. Create query to pull necessary database for reports and QBR data as needed.
# 1. Provide FTP site support to customers as required.
# ---
#
# > <font color = "grey">"We have sought to build and maintain the company's character through principles of honesty, integrity, industry and competence."</font>
